# %%
a= 2

# %%
b= 3

# %%
a+b
# Out:
# 5

# %%
x = 34 - 23 
y = 'Hello'
z = 3.45
if z == 3.45 or y == 'Hello':
  x = x + 1
  y = y + ' World' # String concat.
print(x)
print(y)
# Out:
# 12
# Hello World
